# %%
from google.colab import drive
drive.mount('/content/drive')

import os
os.chdir('/content/drive/My Drive/Big data/Fold_esperimenti')

# !pwd

import warnings
warnings.filterwarnings("ignore")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/Big data/Fold_esperimenti

# %% [markdown]
# ## Preprocessing dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

def process_dataframe(df: pd.DataFrame):

  df = df.drop([ 'Unnamed: 0', 'country', 'age', 'sex', 'apoe4'], axis=1)

  # Calculate the missing rate for each column
  missing_rate = df.isnull().mean()

  # Sort in discending order
  missing_rate_sorted = missing_rate.sort_values(ascending= False)

  # Filter columns that have a missing rate <= 5 %
  threshold = 0.05
  df = df.loc[:, missing_rate <= threshold]

  # Substitute null with zero
  df.fillna(0, inplace=True)

  return df

# %%
from sklearn.preprocessing import MinMaxScaler
def preprocess_metadata(df: pd.DataFrame):

  columns_to_encode = [ 'age', 'sex', 'apoe4']
  df_meta_data = df[columns_to_encode]
  scaler = MinMaxScaler(feature_range=(1, 2))
  df_meta_data['age'] = scaler.fit_transform(df[['age']])
  df_meta_data['sex'] = df_meta_data['sex'].map({'female': 0, 'male': 1}).fillna(3)
  df_meta_data.fillna(0, inplace=True)

  return df_meta_data

# %% [markdown]
# # AUTO ENCODERS

# %%
import numpy as np
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras import regularizers

REG_COEFF = 0.03
DROPOUT_RATE = 0.6

def generate_intermediate_feature(X_train, X_test,
                                  hidden_dim1=256,
                                  hidden_dim2=128,
                                  epochs=100,
                                  batch_size=3):

  """
  Builds and trains a two-layer (256 and 128) autoencoder with
  L2 regularization and dropout, and returns intermediate features (128
  dimensions) for train and test.

  Parameters:
  -----------
  X_train : np.array
  Training feature matrix, shape (num_samples, input_dim)
  X_test : np.array
  Test feature matrix, shape (num_samples, input_dim)
  hidden_dim1 : int
  Size of the first hidden layer (256)
  hidden_dim2 : int
  Size of the second hidden layer (128)
  epochs : int
  Number of epochs to train the autoencoder
  batch_size : int
  Size of the training batch

  Returns:
  ------------
  features_intermediate_train : np.array
  Dimension encoding (num_samples_train, hidden_dim2)
  features_intermediate_test : np.array
  Dimension encoding (num_samples_test, hidden_dim2)
"""

  # Number of input features
  input_dim = X_train.shape[1]

  input_layer = Input(shape=(input_dim,))

  # Encoder
  encoded = Dense(hidden_dim1,
                  activation='relu',
                  kernel_regularizer=regularizers.l2(REG_COEFF)
                  )(input_layer)
  encoded = Dropout(DROPOUT_RATE)(encoded)

  encoded = Dense(hidden_dim2,
                  activation='relu',
                  kernel_regularizer=regularizers.l2(REG_COEFF)
                  )(encoded)
  encoded = Dropout(DROPOUT_RATE)(encoded)

  # Decoder
  decoded = Dense(hidden_dim1,
                  activation='relu',
                  kernel_regularizer=regularizers.l2(REG_COEFF)
                  )(encoded)
  decoded = Dropout(DROPOUT_RATE)(decoded)

  # Output layer
  decoded = Dense(input_dim,
                  activation='sigmoid',
                  kernel_regularizer=regularizers.l2(REG_COEFF)
                  )(decoded)

  # 2. Autoencoder Model Construction
  autoencoder = Model(inputs=input_layer, outputs=decoded)
  autoencoder.compile(optimizer='adam', loss='mse')

  # 3. Training
  autoencoder.fit(X_train, X_train,
                  epochs=epochs,
                  batch_size=batch_size,
                  shuffle=True,
                  validation_data=(X_test, X_test))

  # 4. Creating the encoder model
  encoder = Model(inputs=input_layer, outputs=encoded)

  # 5. Extraction of intermediate features
  features_intermediate_train = encoder.predict(X_train)
  features_intermediate_test = encoder.predict(X_test)

  # 6. Return of features
  return features_intermediate_train, features_intermediate_test

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report


def evaluate_model( X_train, X_test, y_train, y_test ) :
  y_train = y_train.replace({'AD': 0, 'NC': 1, 'MCI': 2})
  y_test = y_test.replace({'AD': 0, 'NC': 1, 'MCI': 2})

  # Random Forest Classifier
  rf_classifier = RandomForestClassifier(n_estimators=31, random_state=42)
  rf_classifier.fit(X_train, y_train)

  y_pred = rf_classifier.predict(X_test)


  print('Results with Random Forest Classifier! \n')
  print(classification_report(y_test, y_pred))

  return classification_report(y_test, y_pred, output_dict=True)

# %% [markdown]
# # MLP Classifier

# %%
from sklearn.neural_network import MLPClassifier
def evaluate_model_mlp( X_train, X_test, y_train, y_test ) :

  y_train = y_train.replace({'AD': 0, 'NC': 1, 'MCI': 2})
  y_test = y_test.replace({'AD': 0, 'NC': 1, 'MCI': 2})

  # MLPClassifier  Classifier
  mlp_classifier = MLPClassifier(max_iter=100, random_state=42)
  mlp_classifier.fit(X_train, y_train)

  y_pred = mlp_classifier.predict(X_test)

  print('Results with MLPClassifier! \n')

  print(classification_report(y_test, y_pred))
  return classification_report(y_test, y_pred, output_dict=True)

# %% [markdown]
# # Preprocessing and Autoencoders

# %%
def checks_columns(df1: pd.DataFrame, df2: pd.DataFrame) -> bool:
    """
    Verifica se due DataFrame hanno le stesse colonne, indipendentemente dall'ordine.

    Parametri:
        df1 (pd.DataFrame): primo DataFrame
        df2 (pd.DataFrame): secondo DataFrame

    Ritorna:
        bool: True se i DataFrame hanno le stesse colonne, False altrimenti.
    """
    return set(df1.columns) == set(df2.columns)

# %%
def remove_columns(df_train, df_test, label_col='disease'):

    y_train = df_train['disease']
    y_test = df_test['disease']

    df_train = df_train.drop('disease', axis=1)
    df_test = df_test.drop('disease', axis=1)

    # Trova le colonne comuni tra df_train e df_test
    colonne_comuni = df_train.columns.intersection(df_test.columns)

    # Mantieni solo le colonne comuni
    df_train_common = df_train[colonne_comuni]
    df_test_common = df_test[colonne_comuni]

    return df_train_common, df_test_common, y_train, y_test

# %%
import pandas as pd

def preprocess_data(df_train, df_test):


    print(checks_columns(df_train, df_test))

    features_mirna_train = process_dataframe(df_train)
    features_mirna_test = process_dataframe(df_test)

    print(checks_columns(features_mirna_train, features_mirna_test))

    features_mirna_train, features_mirna_test, y_train, y_test = remove_columns(features_mirna_train, features_mirna_test)

    intermediate_features_mirna_train, intermediate_features_mirna_test = generate_intermediate_feature(
        features_mirna_train, features_mirna_test)

    features_meta_train = preprocess_metadata(df_train)
    features_meta_test = preprocess_metadata(df_test)

    intermediate_features_meta_train, intermediate_features_meta_test = generate_intermediate_feature(
        features_meta_train, features_meta_test, 15, 15)

    features_final_train = concatenate_features(features_meta_train, intermediate_features_mirna_train)
    features_final_test = concatenate_features(features_meta_test, intermediate_features_mirna_test)


    return features_final_train, features_final_test, y_train, y_test

def evaluate_models(features_train, features_test, y_train, y_test):
    report_dict_0 = evaluate_model(features_train, features_test, y_train, y_test)
    report_dict_1 = evaluate_model_mlp(features_train, features_test, y_train, y_test)
    return report_dict_0, report_dict_1

# %%
def concatenate_features(features1, features2):
    return np.concatenate((features1, features2), axis=1)

# %% [markdown]
# # Cross-dataset Result
# Train df_84_93_23.csv'
# Test 'df_89.csv'

# %%
train_path = pd.read_csv('df_84_93_23.csv')
test_path = pd.read_csv('df_89.csv')
features_train, features_test, y_train, y_test = preprocess_data(train_path, test_path)
# Out:
# True
# False
# Epoch 1/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 11s 21ms/step - loss: 2859.8679 - val_loss: 5.1700
# Epoch 2/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - loss: 2239.0596 - val_loss: 5.2662
# Epoch 3/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - loss: 3190.2937 - val_loss: 5.4546
# Epoch 4/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 20s 23ms/step - loss: 3356.4944 - val_loss: 5.5658
# Epoch 5/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 11s 26ms/step - loss: 2194.6609 - val_loss: 5.6746
# Epoch 6/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 2540.4829 - val_loss: 5.9049
# Epoch 7/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - loss: 2207.5889 - val_loss: 5.9963
# Epoch 8/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - loss: 2623.7241 - val_loss: 6.0746
# Epoch 9/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 3500.4910 - val_loss: 6.1853
# Epoch 10/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - loss: 2582.7869 - val_loss: 6.2466
# Epoch 11/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - loss: 2336.7783 - val_loss: 6.3546
# Epoch 12/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 2246.3699 - val_loss: 6.3999
# Epoch 13/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 2458.2490 - val_loss: 6.4235
# Epoch 14/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - loss: 2711.1160 - val_loss: 6.4606
# Epoch 15/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - loss: 2905.2646 - val_loss: 6.4752
# Epoch 16/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 2614.1450 - val_loss: 6.5084
# Epoch 17/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - loss: 2256.0769 - val_loss: 6.4936
# Epoch 18/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - loss: 2449.8909 - val_loss: 6.4767
# Epoch 19/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - loss: 1981.8269 - val_loss: 6.4868
# Epoch 20/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - loss: 2072.8528 - val_loss: 6.4812
# Epoch 21/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 1795.9381 - val_loss: 6.4745
# Epoch 22/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 2564.5029 - val_loss: 6.4746
# Epoch 23/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - loss: 2441.6440 - val_loss: 6.4792
# Epoch 24/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - loss: 2152.6870 - val_loss: 6.4739
# Epoch 25/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 2329.2861 - val_loss: 6.4714
# Epoch 26/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - loss: 1938.8221 - val_loss: 6.4802
# Epoch 27/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 2326.1917 - val_loss: 6.4791
# Epoch 28/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 2372.2922 - val_loss: 6.4741
# Epoch 29/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - loss: 2597.9419 - val_loss: 6.4753
# Epoch 30/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - loss: 2435.7634 - val_loss: 6.4798
# Epoch 31/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - loss: 3353.7549 - val_loss: 6.4677
# Epoch 32/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - loss: 2643.8110 - val_loss: 6.4771
# Epoch 33/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - loss: 2413.6802 - val_loss: 6.4775
# Epoch 34/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step - loss: 3758.0239 - val_loss: 6.4710
# Epoch 35/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - loss: 2436.3379 - val_loss: 6.4757
# Epoch 36/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - loss: 2548.3645 - val_loss: 6.4750
# Epoch 37/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - loss: 2160.9229 - val_loss: 6.4829
# Epoch 38/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 3405.0610 - val_loss: 6.4801
# Epoch 39/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - loss: 2285.5898 - val_loss: 6.4801
# Epoch 40/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 2067.5850 - val_loss: 6.4804
# Epoch 41/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - loss: 3065.7620 - val_loss: 6.4710
# Epoch 42/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 19s 20ms/step - loss: 2797.1265 - val_loss: 6.4762
# Epoch 43/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - loss: 2258.4226 - val_loss: 6.4752
# Epoch 44/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - loss: 2358.1602 - val_loss: 6.4812
# Epoch 45/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - loss: 2729.9661 - val_loss: 6.4772
# Epoch 46/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 2733.5010 - val_loss: 6.4826
# Epoch 47/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - loss: 2179.9949 - val_loss: 6.4799
# Epoch 48/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - loss: 3226.4148 - val_loss: 6.4800
# Epoch 49/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 1979.0175 - val_loss: 6.4760
# Epoch 50/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 11s 21ms/step - loss: 3227.3193 - val_loss: 6.4767
# Epoch 51/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - loss: 3030.0779 - val_loss: 6.4692
# Epoch 52/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - loss: 2630.1475 - val_loss: 6.4742
# Epoch 53/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 2795.2346 - val_loss: 6.4730
# Epoch 54/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - loss: 2152.0664 - val_loss: 6.4745
# Epoch 55/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - loss: 2264.8057 - val_loss: 6.4746
# Epoch 56/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 2740.8264 - val_loss: 6.4700
# Epoch 57/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - loss: 3000.0356 - val_loss: 6.4727
# Epoch 58/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - loss: 2627.5276 - val_loss: 6.4749
# Epoch 59/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - loss: 2235.3123 - val_loss: 6.4750
# Epoch 60/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - loss: 2982.3760 - val_loss: 6.4716
# Epoch 61/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - loss: 2395.4802 - val_loss: 6.4755
# Epoch 62/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 1983.8958 - val_loss: 6.4752
# Epoch 63/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 2463.0300 - val_loss: 6.4738
# Epoch 64/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - loss: 2148.7566 - val_loss: 6.4744
# Epoch 65/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - loss: 2870.4036 - val_loss: 6.4762
# Epoch 66/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step - loss: 2153.6133 - val_loss: 6.4695
# Epoch 67/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - loss: 2178.5637 - val_loss: 6.4708
# Epoch 68/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - loss: 2536.6938 - val_loss: 6.4760
# Epoch 69/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - loss: 2042.5735 - val_loss: 6.4771
# Epoch 70/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - loss: 2716.8882 - val_loss: 6.4714
# Epoch 71/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - loss: 2327.6304 - val_loss: 6.4697
# Epoch 72/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - loss: 2515.3425 - val_loss: 6.4725
# Epoch 73/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - loss: 2149.7019 - val_loss: 6.4771
# Epoch 74/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - loss: 2877.1917 - val_loss: 6.4689
# Epoch 75/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - loss: 2695.8594 - val_loss: 6.4728
# Epoch 76/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 2684.3455 - val_loss: 6.4756
# Epoch 77/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - loss: 2563.5657 - val_loss: 6.4742
# Epoch 78/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - loss: 2656.9905 - val_loss: 6.4720
# Epoch 79/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step - loss: 2323.5881 - val_loss: 6.4729
# Epoch 80/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 1612.3590 - val_loss: 6.4763
# Epoch 81/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - loss: 2240.0925 - val_loss: 6.4728
# Epoch 82/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 2151.8713 - val_loss: 6.4710
# Epoch 83/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - loss: 2772.5898 - val_loss: 6.4740
# Epoch 84/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - loss: 2367.0667 - val_loss: 6.4700
# Epoch 85/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 2074.3635 - val_loss: 6.4707
# Epoch 86/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 19s 21ms/step - loss: 2576.8257 - val_loss: 6.4759
# Epoch 87/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - loss: 2172.8975 - val_loss: 6.4729
# Epoch 88/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - loss: 2709.5823 - val_loss: 6.4733
# Epoch 89/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - loss: 2590.4419 - val_loss: 6.4724
# Epoch 90/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 2580.8840 - val_loss: 6.4712
# Epoch 91/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - loss: 2518.7830 - val_loss: 6.4705
# Epoch 92/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 11s 27ms/step - loss: 2673.1548 - val_loss: 6.4758
# Epoch 93/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 19s 25ms/step - loss: 2080.8457 - val_loss: 6.4747
# Epoch 94/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 20s 24ms/step - loss: 2993.1536 - val_loss: 6.4694
# Epoch 95/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - loss: 3440.7141 - val_loss: 6.4710
# Epoch 96/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 12s 24ms/step - loss: 2656.8899 - val_loss: 6.4727
# Epoch 97/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 2909.7122 - val_loss: 6.4706
# Epoch 98/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - loss: 2183.5837 - val_loss: 6.4692
# Epoch 99/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - loss: 2291.0530 - val_loss: 6.4711
# Epoch 100/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - loss: 2636.8992 - val_loss: 6.4690
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Epoch 1/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 3.0046 - val_loss: 2.1775
# Epoch 2/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 2.0938 - val_loss: 1.9877
# Epoch 3/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.8482 - val_loss: 1.8859
# Epoch 4/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.7525 - val_loss: 1.8363
# Epoch 5/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.7081 - val_loss: 1.8096
# Epoch 6/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.6743 - val_loss: 1.7932
# Epoch 7/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.6488 - val_loss: 1.7797
# Epoch 8/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.6268 - val_loss: 1.7655
# Epoch 9/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.6198 - val_loss: 1.7564
# Epoch 10/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.6120 - val_loss: 1.7644
# Epoch 11/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.6030 - val_loss: 1.7642
# Epoch 12/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.6034 - val_loss: 1.7479
# Epoch 13/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.5946 - val_loss: 1.7431
# Epoch 14/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5765 - val_loss: 1.7561
# Epoch 15/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5825 - val_loss: 1.7416
# Epoch 16/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5849 - val_loss: 1.7449
# Epoch 17/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5770 - val_loss: 1.7455
# Epoch 18/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5718 - val_loss: 1.7379
# Epoch 19/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5631 - val_loss: 1.7546
# Epoch 20/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5717 - val_loss: 1.7378
# Epoch 21/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5747 - val_loss: 1.7338
# Epoch 22/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.5632 - val_loss: 1.7320
# Epoch 23/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 1.5584 - val_loss: 1.7422
# Epoch 24/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.5648 - val_loss: 1.7340
# Epoch 25/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.5723 - val_loss: 1.7412
# Epoch 26/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5610 - val_loss: 1.7590
# Epoch 27/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5671 - val_loss: 1.7388
# Epoch 28/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5687 - val_loss: 1.7347
# Epoch 29/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.5576 - val_loss: 1.7455
# Epoch 30/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.5618 - val_loss: 1.7456
# Epoch 31/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5644 - val_loss: 1.7355
# Epoch 32/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.5560 - val_loss: 1.7433
# Epoch 33/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.5545 - val_loss: 1.7455
# Epoch 34/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5640 - val_loss: 1.7386
# Epoch 35/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5651 - val_loss: 1.7307
# Epoch 36/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5635 - val_loss: 1.7201
# Epoch 37/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.5610 - val_loss: 1.7475
# Epoch 38/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5783 - val_loss: 1.7207
# Epoch 39/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.5648 - val_loss: 1.7372
# Epoch 40/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5612 - val_loss: 1.7335
# Epoch 41/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5544 - val_loss: 1.7507
# Epoch 42/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5574 - val_loss: 1.7304
# Epoch 43/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5553 - val_loss: 1.7465
# Epoch 44/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.5569 - val_loss: 1.7376
# Epoch 45/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 1.5582 - val_loss: 1.7358
# Epoch 46/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.5611 - val_loss: 1.7422
# Epoch 47/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5547 - val_loss: 1.7385
# Epoch 48/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5532 - val_loss: 1.7379
# Epoch 49/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5601 - val_loss: 1.7364
# Epoch 50/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5557 - val_loss: 1.7257
# Epoch 51/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5592 - val_loss: 1.7353
# Epoch 52/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5614 - val_loss: 1.7459
# Epoch 53/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5552 - val_loss: 1.7407
# Epoch 54/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.5619 - val_loss: 1.7495
# Epoch 55/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.5584 - val_loss: 1.7287
# Epoch 56/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5649 - val_loss: 1.7323
# Epoch 57/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5620 - val_loss: 1.7314
# Epoch 58/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5623 - val_loss: 1.7471
# Epoch 59/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5561 - val_loss: 1.7492
# Epoch 60/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5595 - val_loss: 1.7491
# Epoch 61/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5707 - val_loss: 1.7347
# Epoch 62/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.5585 - val_loss: 1.7396
# Epoch 63/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.5552 - val_loss: 1.7344
# Epoch 64/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.5643 - val_loss: 1.7315
# Epoch 65/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5526 - val_loss: 1.7373
# Epoch 66/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5626 - val_loss: 1.7372
# Epoch 67/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5598 - val_loss: 1.7299
# Epoch 68/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5588 - val_loss: 1.7304
# Epoch 69/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5637 - val_loss: 1.7322
# Epoch 70/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5670 - val_loss: 1.7362
# Epoch 71/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.5597 - val_loss: 1.7339
# Epoch 72/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.5712 - val_loss: 1.7377
# Epoch 73/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5534 - val_loss: 1.7389
# Epoch 74/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5594 - val_loss: 1.7355
# Epoch 75/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5530 - val_loss: 1.7395
# Epoch 76/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5597 - val_loss: 1.7335
# Epoch 77/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5689 - val_loss: 1.7380
# Epoch 78/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5528 - val_loss: 1.7471
# Epoch 79/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.5616 - val_loss: 1.7386
# Epoch 80/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.5587 - val_loss: 1.7394
# Epoch 81/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.5517 - val_loss: 1.7253
# Epoch 82/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5691 - val_loss: 1.7336
# Epoch 83/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5649 - val_loss: 1.7319
# Epoch 84/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5609 - val_loss: 1.7337
# Epoch 85/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5685 - val_loss: 1.7333
# Epoch 86/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5717 - val_loss: 1.7332
# Epoch 87/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5593 - val_loss: 1.7329
# Epoch 88/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 1.5601 - val_loss: 1.7366
# Epoch 89/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.5519 - val_loss: 1.7484
# Epoch 90/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 1.5598 - val_loss: 1.7291
# Epoch 91/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5600 - val_loss: 1.7386
# Epoch 92/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5727 - val_loss: 1.7370
# Epoch 93/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5527 - val_loss: 1.7338
# Epoch 94/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5601 - val_loss: 1.7459
# Epoch 95/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5587 - val_loss: 1.7453
# Epoch 96/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5511 - val_loss: 1.7310
# Epoch 97/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 1.5621 - val_loss: 1.7389
# Epoch 98/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.5633 - val_loss: 1.7341
# Epoch 99/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5643 - val_loss: 1.7286
# Epoch 100/100
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.5563 - val_loss: 1.7465
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step

# %%
report_dict_0, report_dict_1 = evaluate_models(features_train, features_test, y_train, y_test)
# Out:
# Results with Random Forest Classifier!
#
#               precision    recall  f1-score   support
#
#            0       0.35      1.00      0.51        28
#            1       0.00      0.00      0.00        21
#            2       0.00      0.00      0.00        32
#
#     accuracy                           0.35        81
#    macro avg       0.12      0.33      0.17        81
# weighted avg       0.12      0.35      0.18        81
#
# Results with MLPClassifier!
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        28
#            1       0.26      1.00      0.41        21
#            2       0.00      0.00      0.00        32
#
#     accuracy                           0.26        81
#    macro avg       0.09      0.33      0.14        81
# weighted avg       0.07      0.26      0.11        81

# %% [markdown]
# # Intra-dataset Results

# %%
df = pd.read_csv('df_89.csv')
train_3, test_3 = train_test_split(df, test_size=0.5, random_state=42)
features_train_3, features_test_3, y_train_3, y_test_3 = preprocess_data(train_3, test_3)
report_dict_3_0, report_dict_3_1 = evaluate_models(features_train_3, features_test_3, y_train_3, y_test_3)
# Out:
# True
# True
# Epoch 1/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 37.3326 - val_loss: 22.4408
# Epoch 2/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 19.4651 - val_loss: 12.3076
# Epoch 3/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 11.0565 - val_loss: 7.9779
# Epoch 4/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 7.4292 - val_loss: 6.1213
# Epoch 5/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 5.8368 - val_loss: 5.1830
# Epoch 6/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 5.0212 - val_loss: 4.5915
# Epoch 7/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 4.5082 - val_loss: 4.2114
# Epoch 8/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 4.1570 - val_loss: 3.9676
# Epoch 9/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 3.9322 - val_loss: 3.7899
# Epoch 10/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 3.7832 - val_loss: 3.7081
# Epoch 11/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 3.6625 - val_loss: 3.6118
# Epoch 12/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 3.6171 - val_loss: 3.5785
# Epoch 13/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 3.5735 - val_loss: 3.5551
# Epoch 14/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 3.5462 - val_loss: 3.5202
# Epoch 15/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 3.5139 - val_loss: 3.5328
# Epoch 16/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 3.5342 - val_loss: 3.4971
# Epoch 17/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 3.4984 - val_loss: 3.4919
# Epoch 18/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 3.4963 - val_loss: 3.5022
# Epoch 19/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 3.4917 - val_loss: 3.4888
# Epoch 20/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 3.5178 - val_loss: 3.4831
# Epoch 21/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 3.5146 - val_loss: 3.4919
# Epoch 22/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 3.4864 - val_loss: 3.4832
# Epoch 23/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 3.4597 - val_loss: 3.4867
# Epoch 24/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 3.4765 - val_loss: 3.4828
# Epoch 25/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 3.4690 - val_loss: 3.4776
# Epoch 26/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 3.4727 - val_loss: 3.4809
# Epoch 27/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 3.4962 - val_loss: 3.4792
# Epoch 28/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 3.4769 - val_loss: 3.4776
# Epoch 29/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 3.5025 - val_loss: 3.4819
# Epoch 30/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 3.5055 - val_loss: 3.4854
# Epoch 31/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 3.4829 - val_loss: 3.4918
# Epoch 32/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 3.4885 - val_loss: 3.4932
# Epoch 33/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 3.5011 - val_loss: 3.4770
# Epoch 34/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 3.4613 - val_loss: 3.4757
# Epoch 35/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 3.5193 - val_loss: 3.4799
# Epoch 36/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 3.4506 - val_loss: 3.4756
# Epoch 37/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 3.4750 - val_loss: 3.4774
# Epoch 38/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 3.4602 - val_loss: 3.4930
# Epoch 39/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 3.4938 - val_loss: 3.4856
# Epoch 40/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 3.4816 - val_loss: 3.4942
# Epoch 41/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 3.5029 - val_loss: 3.4753
# Epoch 42/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 3.4880 - val_loss: 3.4847
# Epoch 43/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 3.4883 - val_loss: 3.4837
# Epoch 44/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 3.5070 - val_loss: 3.4790
# Epoch 45/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 3.4878 - val_loss: 3.4975
# Epoch 46/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 3.4786 - val_loss: 3.4890
# Epoch 47/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 3.4704 - val_loss: 3.4749
# Epoch 48/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 3.4703 - val_loss: 3.4732
# Epoch 49/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 3.5131 - val_loss: 3.4811
# Epoch 50/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 3.4814 - val_loss: 3.4801
# Epoch 51/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 3.4862 - val_loss: 3.4916
# Epoch 52/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 3.4861 - val_loss: 3.4965
# Epoch 53/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 3.4880 - val_loss: 3.4832
# Epoch 54/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 3.4716 - val_loss: 3.4711
# Epoch 55/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 3.4733 - val_loss: 3.4803
# Epoch 56/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 3.4629 - val_loss: 3.5054
# Epoch 57/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 3.4706 - val_loss: 3.4912
# Epoch 58/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 3.4543 - val_loss: 3.4780
# Epoch 59/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 3.4772 - val_loss: 3.4722
# Epoch 60/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 3.5060 - val_loss: 3.4755
# Epoch 61/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 3.4774 - val_loss: 3.4753
# Epoch 62/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 3.4737 - val_loss: 3.4775
# Epoch 63/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 3.4801 - val_loss: 3.4828
# Epoch 64/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 3.4729 - val_loss: 3.4798
# Epoch 65/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 3.4523 - val_loss: 3.4696
# Epoch 66/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 3.4727 - val_loss: 3.4700
# Epoch 67/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 3.4341 - val_loss: 3.4778
# Epoch 68/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 3.5016 - val_loss: 3.4782
# Epoch 69/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 3.5036 - val_loss: 3.4804
# Epoch 70/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 3.5092 - val_loss: 3.4796
# Epoch 71/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 3.4778 - val_loss: 3.4796
# Epoch 72/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 3.4617 - val_loss: 3.4782
# Epoch 73/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 3.4445 - val_loss: 3.4793
# Epoch 74/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 3.4542 - val_loss: 3.4706
# Epoch 75/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 3.4843 - val_loss: 3.4678
# Epoch 76/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 3.4918 - val_loss: 3.4736
# Epoch 77/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 3.4924 - val_loss: 3.4762
# Epoch 78/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 3.4461 - val_loss: 3.4682
# Epoch 79/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 3.4574 - val_loss: 3.4710
# Epoch 80/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 3.4874 - val_loss: 3.4689
# Epoch 81/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 3.4655 - val_loss: 3.4724
# Epoch 82/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 3.4594 - val_loss: 3.4861
# Epoch 83/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 3.4668 - val_loss: 3.4789
# Epoch 84/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 3.4660 - val_loss: 3.4696
# Epoch 85/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 3.4571 - val_loss: 3.4707
# Epoch 86/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 3.4570 - val_loss: 3.4737
# Epoch 87/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 3.4916 - val_loss: 3.4761
# Epoch 88/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 3.4650 - val_loss: 3.4826
# Epoch 89/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 3.4595 - val_loss: 3.4953
# Epoch 90/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 3.4522 - val_loss: 3.4809
# Epoch 91/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 3.4619 - val_loss: 3.4867
# Epoch 92/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 3.4746 - val_loss: 3.4759
# Epoch 93/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 3.4536 - val_loss: 3.4681
# Epoch 94/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 3.4871 - val_loss: 3.4692
# Epoch 95/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 3.4841 - val_loss: 3.4667
# Epoch 96/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 3.4876 - val_loss: 3.4685
# Epoch 97/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 3.4903 - val_loss: 3.4723
# Epoch 98/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 3.4668 - val_loss: 3.4673
# Epoch 99/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 3.4647 - val_loss: 3.4688
# Epoch 100/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 3.4545 - val_loss: 3.4693
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Epoch 1/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 3.1106 - val_loss: 2.9862
# Epoch 2/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.0468 - val_loss: 2.8689
# Epoch 3/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.9848 - val_loss: 2.7627
# Epoch 4/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.8300 - val_loss: 2.6682
# Epoch 5/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.8158 - val_loss: 2.5780
# Epoch 6/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.7325 - val_loss: 2.4986
# Epoch 7/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.5428 - val_loss: 2.4256
# Epoch 8/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.6768 - val_loss: 2.3567
# Epoch 9/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.5074 - val_loss: 2.2917
# Epoch 10/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.5132 - val_loss: 2.2296
# Epoch 11/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.4140 - val_loss: 2.1727
# Epoch 12/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.3628 - val_loss: 2.1214
# Epoch 13/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.2737 - val_loss: 2.0738
# Epoch 14/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.2062 - val_loss: 2.0313
# Epoch 15/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.2152 - val_loss: 1.9944
# Epoch 16/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.1208 - val_loss: 1.9599
# Epoch 17/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.1978 - val_loss: 1.9292
# Epoch 18/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.1269 - val_loss: 1.9008
# Epoch 19/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0453 - val_loss: 1.8749
# Epoch 20/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.0164 - val_loss: 1.8513
# Epoch 21/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.9456 - val_loss: 1.8294
# Epoch 22/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.0116 - val_loss: 1.8096
# Epoch 23/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.9484 - val_loss: 1.7901
# Epoch 24/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.9193 - val_loss: 1.7724
# Epoch 25/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.9146 - val_loss: 1.7566
# Epoch 26/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.8612 - val_loss: 1.7426
# Epoch 27/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.8714 - val_loss: 1.7294
# Epoch 28/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.8350 - val_loss: 1.7170
# Epoch 29/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.8629 - val_loss: 1.7053
# Epoch 30/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.8276 - val_loss: 1.6942
# Epoch 31/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.8699 - val_loss: 1.6836
# Epoch 32/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7815 - val_loss: 1.6736
# Epoch 33/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.7571 - val_loss: 1.6642
# Epoch 34/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7460 - val_loss: 1.6551
# Epoch 35/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7248 - val_loss: 1.6463
# Epoch 36/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7037 - val_loss: 1.6380
# Epoch 37/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7599 - val_loss: 1.6304
# Epoch 38/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.6696 - val_loss: 1.6227
# Epoch 39/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7398 - val_loss: 1.6158
# Epoch 40/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7284 - val_loss: 1.6094
# Epoch 41/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6811 - val_loss: 1.6032
# Epoch 42/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6756 - val_loss: 1.5966
# Epoch 43/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6346 - val_loss: 1.5902
# Epoch 44/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6788 - val_loss: 1.5842
# Epoch 45/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6361 - val_loss: 1.5783
# Epoch 46/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6373 - val_loss: 1.5728
# Epoch 47/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6392 - val_loss: 1.5675
# Epoch 48/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6327 - val_loss: 1.5628
# Epoch 49/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6372 - val_loss: 1.5593
# Epoch 50/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5982 - val_loss: 1.5554
# Epoch 51/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6040 - val_loss: 1.5512
# Epoch 52/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5748 - val_loss: 1.5466
# Epoch 53/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5826 - val_loss: 1.5421
# Epoch 54/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5896 - val_loss: 1.5383
# Epoch 55/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5722 - val_loss: 1.5345
# Epoch 56/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6343 - val_loss: 1.5312
# Epoch 57/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.6061 - val_loss: 1.5282
# Epoch 58/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5883 - val_loss: 1.5244
# Epoch 59/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5562 - val_loss: 1.5209
# Epoch 60/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5383 - val_loss: 1.5173
# Epoch 61/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5956 - val_loss: 1.5141
# Epoch 62/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.5717 - val_loss: 1.5114
# Epoch 63/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5507 - val_loss: 1.5088
# Epoch 64/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5458 - val_loss: 1.5064
# Epoch 65/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5489 - val_loss: 1.5037
# Epoch 66/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5518 - val_loss: 1.5014
# Epoch 67/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5591 - val_loss: 1.4995
# Epoch 68/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5438 - val_loss: 1.4974
# Epoch 69/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.5315 - val_loss: 1.4951
# Epoch 70/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.5363 - val_loss: 1.4933
# Epoch 71/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.5159 - val_loss: 1.4910
# Epoch 72/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.5594 - val_loss: 1.4893
# Epoch 73/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.5602 - val_loss: 1.4877
# Epoch 74/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.5558 - val_loss: 1.4856
# Epoch 75/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.5237 - val_loss: 1.4838
# Epoch 76/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.5022 - val_loss: 1.4816
# Epoch 77/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.5197 - val_loss: 1.4805
# Epoch 78/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.5061 - val_loss: 1.4786
# Epoch 79/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.5501 - val_loss: 1.4766
# Epoch 80/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5283 - val_loss: 1.4753
# Epoch 81/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5168 - val_loss: 1.4739
# Epoch 82/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4965 - val_loss: 1.4723
# Epoch 83/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5270 - val_loss: 1.4715
# Epoch 84/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4812 - val_loss: 1.4696
# Epoch 85/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4790 - val_loss: 1.4675
# Epoch 86/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5002 - val_loss: 1.4659
# Epoch 87/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4906 - val_loss: 1.4641
# Epoch 88/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4873 - val_loss: 1.4623
# Epoch 89/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.4842 - val_loss: 1.4608
# Epoch 90/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5345 - val_loss: 1.4598
# Epoch 91/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4952 - val_loss: 1.4591
# Epoch 92/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4792 - val_loss: 1.4581
# Epoch 93/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4681 - val_loss: 1.4569
# Epoch 94/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4886 - val_loss: 1.4554
# Epoch 95/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4753 - val_loss: 1.4543
# Epoch 96/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4912 - val_loss: 1.4532
# Epoch 97/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4652 - val_loss: 1.4520
# Epoch 98/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4694 - val_loss: 1.4510
# Epoch 99/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4780 - val_loss: 1.4501
# Epoch 100/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4592 - val_loss: 1.4488
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Results with Random Forest Classifier!
#
#               precision    recall  f1-score   support
#
#            0       0.25      0.23      0.24        13
#            1       0.17      0.20      0.18        10
#            2       0.35      0.33      0.34        18
#
#     accuracy                           0.27        41
#    macro avg       0.26      0.25      0.25        41
# weighted avg       0.27      0.27      0.27        41
#
# Results with MLPClassifier!
#
#               precision    recall  f1-score   support
#
#            0       0.32      1.00      0.48        13
#            1       0.00      0.00      0.00        10
#            2       0.00      0.00      0.00        18
#
#     accuracy                           0.32        41
#    macro avg       0.11      0.33      0.16        41
# weighted avg       0.10      0.32      0.15        41
