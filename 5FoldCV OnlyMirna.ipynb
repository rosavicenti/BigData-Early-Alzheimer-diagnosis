# %%
from google.colab import drive
drive.mount('/content/drive')

import os
os.chdir('/content/drive/My Drive/Big data/Fold_esperimenti')

# !pwd

import warnings
warnings.filterwarnings("ignore")
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/Big data/Fold_esperimenti

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def print_average_metrics(report_dict_0, report_dict_1, report_dict_2, report_dict_3, report_dict_4):
  macro_metrics_0 = report_dict_0.get("macro avg", {})
  macro_metrics_1 = report_dict_1.get("macro avg", {})
  macro_metrics_2 = report_dict_2.get("macro avg", {})
  macro_metrics_3 = report_dict_3.get("macro avg", {})
  macro_metrics_4 = report_dict_4.get("macro avg", {})

  # Average precision score
  average_precision_score = (macro_metrics_0.get("precision", {}) +
                              macro_metrics_1.get("precision", {}) +
                              macro_metrics_2.get("precision", {}) +
                              macro_metrics_3.get("precision", {}) +
                              macro_metrics_4.get("precision", {})
                              ) / 5

  # Average Reacall score
  average_recall_score = (macro_metrics_0.get("recall", {}) +
                        macro_metrics_1.get("recall", {}) +
                        macro_metrics_2.get("recall", {}) +
                        macro_metrics_3.get("recall", {}) +
                        macro_metrics_4.get("recall", {})
                        ) / 5
  # Average F1 Score
  average_f1_score = (macro_metrics_0.get("f1-score", {}) +
                    macro_metrics_1.get("f1-score", {}) +
                    macro_metrics_2.get("f1-score", {}) +
                    macro_metrics_3.get("f1-score", {}) +
                    macro_metrics_4.get("f1-score", {})
                   ) / 5

  print("Average Precision Score:", round(average_precision_score, 2))
  print("Average Recall Score:", round(average_recall_score, 2))
  print("Average F1 Score:", round(average_f1_score, 2))

# %% [markdown]
# #Preprocessing dataset

# %% [markdown]
# ## Mirna Preprocessing

# %%
def process_dataframe(df: pd.DataFrame):

  # Calculate the missing rate for each column
  missing_rate = df.isnull().mean()

  # Sort in discending order
  missing_rate_sorted = missing_rate.sort_values(ascending= False)

  # Filter columns that have a missing rate <= 5 %
  threshold = 0.05
  df = df.loc[:, missing_rate <= threshold]

  # Substitute null with zero
  df.fillna(0, inplace=True)

  df = df.drop(['disease', 'country',  'Unnamed: 0', 'age', 'sex', 'apoe4'], axis=1)

  # Substitute null with zero
  df.fillna(0, inplace=True)

  return df

# %% [markdown]
# ## Metadata Preprocessing

# %%
from sklearn.preprocessing import MinMaxScaler
def preprocess_metadata(df: pd.DataFrame):

  columns_to_encode = [ 'age', 'sex', 'apoe4']
  df_meta_data = df[columns_to_encode]
  scaler = MinMaxScaler(feature_range=(1, 2))
  df_meta_data['age'] = scaler.fit_transform(df[['age']])
  df_meta_data['sex'] = df_meta_data['sex'].map({'female': 0, 'male': 1}).fillna(3)
  df_meta_data.fillna(0, inplace=True)

  return df_meta_data

# %% [markdown]
# # Autoencoder

# %%
import numpy as np
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras import regularizers

REG_COEFF = 0.03
DROPOUT_RATE = 0.6

def generate_intermediate_feature(X_train, X_test,
                                  hidden_dim1=256,
                                  hidden_dim2=128,
                                  epochs=100,
                                  batch_size=256):
    """
    Costruisce e addestra un autoencoder a due livelli (256 e 128) con
    regolarizzazione L2 e dropout, e restituisce le feature intermedie (128
    dimensioni) per train e test.

    Parametri:
    -----------
    X_train : np.array
        Matrice delle feature di training, shape (num_samples, input_dim)
    X_test  : np.array
        Matrice delle feature di test, shape (num_samples, input_dim)
    hidden_dim1 : int
        Dimensione del primo livello nascosto (es. 256)
    hidden_dim2 : int
        Dimensione del secondo livello nascosto (es. 128, il bottleneck)
    epochs : int
        Numero di epoche per l'addestramento dell'autoencoder
    batch_size : int
        Dimensione del batch per l'addestramento

    Restituisce:
    ------------
    features_intermediate_train : np.array
        Codifica di dimensione (num_samples_train, hidden_dim2)
    features_intermediate_test : np.array
        Codifica di dimensione (num_samples_test, hidden_dim2)
    """

    # Numero di feature in ingresso
    input_dim = X_train.shape[1]

    # 1. Definizione dei layer
    input_layer = Input(shape=(input_dim,))

    # Encoder
    encoded = Dense(hidden_dim1,
                    activation='relu',
                    kernel_regularizer=regularizers.l2(REG_COEFF)
                   )(input_layer)
    encoded = Dropout(DROPOUT_RATE)(encoded)

    encoded = Dense(hidden_dim2,
                    activation='relu',
                    kernel_regularizer=regularizers.l2(REG_COEFF)
                   )(encoded)
    encoded = Dropout(DROPOUT_RATE)(encoded)

    # Decoder
    decoded = Dense(hidden_dim1,
                    activation='relu',
                    kernel_regularizer=regularizers.l2(REG_COEFF)
                   )(encoded)
    decoded = Dropout(DROPOUT_RATE)(decoded)

    # Output layer
    decoded = Dense(input_dim,
                    activation='sigmoid',
                    kernel_regularizer=regularizers.l2(REG_COEFF)
                   )(decoded)

    # 2. Costruzione del modello Autoencoder
    autoencoder = Model(inputs=input_layer, outputs=decoded)
    autoencoder.compile(optimizer='adam', loss='mse')

    # 3. Addestramento
    autoencoder.fit(X_train, X_train,
                    epochs=epochs,
                    batch_size=batch_size,
                    shuffle=True,
                    validation_data=(X_test, X_test))

    # 4. Creazione del modello encoder
    # (l'output finale del nostro encoder è 'encoded' dopo il secondo Dropout)
    encoder = Model(inputs=input_layer, outputs=encoded)

    # 5. Estrazione delle feature intermedie
    features_intermediate_train = encoder.predict(X_train)
    features_intermediate_test = encoder.predict(X_test)

    # 6. Ritorno delle feature
    return features_intermediate_train, features_intermediate_test

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

def evaluate_model_rf( X_train, X_test, y_train, y_test ) :

  y_train = y_train.replace({'AD': 0, 'NC': 1, 'MCI': 2})
  y_test = y_test.replace({'AD': 0, 'NC': 1, 'MCI': 2})

  # Random Forest Classifier
  rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
  rf_classifier.fit(X_train, y_train)

  y_pred = rf_classifier.predict(X_test)

  print(classification_report(y_test, y_pred))
  return classification_report(y_test, y_pred, output_dict=True)

# %% [markdown]
# # MLP Classifier

# %%
from sklearn.neural_network import MLPClassifier
def evaluate_model_mlp( X_train, X_test, y_train, y_test ) :

  y_train = y_train.replace({'AD': 0, 'NC': 1, 'MCI': 2})
  y_test = y_test.replace({'AD': 0, 'NC': 1, 'MCI': 2})

  # MLPClassifier  Classifier
  mlp_classifier = MLPClassifier(max_iter=100, random_state=42)
  mlp_classifier.fit(X_train, y_train)

  y_pred = mlp_classifier.predict(X_test)



  print(classification_report(y_test, y_pred, ))
  return classification_report(y_test, y_pred, output_dict=True)

# %%
def concatenate_features(features1, features2):
    return np.concatenate((features1, features2), axis=1)

# %% [markdown]
# # Fold 0 - Results

# %%
import pandas as pd

df0_train = pd.read_csv('train_fold_0.csv')
df0_test = pd.read_csv('test_fold_0.csv')

df_mirna_preprocessed_train_0 = process_dataframe(df0_train)
df_mirna_preprocessed_test_0 = process_dataframe(df0_test)


mirna_features_intermediate_train_0, mirna_features_intermediate_test_0 = generate_intermediate_feature(df_mirna_preprocessed_train_0, df_mirna_preprocessed_test_0)
# Out:
# Epoch 1/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 128ms/step - loss: 2418.9363 - val_loss: 1660.1184
# Epoch 2/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 2426.2441 - val_loss: 1652.0940
# Epoch 3/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 2743.8884 - val_loss: 1646.5133
# Epoch 4/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 2592.6553 - val_loss: 1642.2794
# Epoch 5/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 2648.4802 - val_loss: 1639.0652
# Epoch 6/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 2369.8984 - val_loss: 1636.7317
# Epoch 7/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 2707.5762 - val_loss: 1635.0894
# Epoch 8/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 2300.4944 - val_loss: 1633.9380
# Epoch 9/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 2694.6633 - val_loss: 1633.1116
# Epoch 10/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 2208.5950 - val_loss: 1632.5009
# Epoch 11/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 2328.9956 - val_loss: 1632.0344
# Epoch 12/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 2562.9517 - val_loss: 1631.6622
# Epoch 13/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 2253.2605 - val_loss: 1631.3499
# Epoch 14/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 2108.2678 - val_loss: 1631.0887
# Epoch 15/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 2889.0208 - val_loss: 1630.8629
# Epoch 16/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 2587.0581 - val_loss: 1630.6682
# Epoch 17/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 2294.7715 - val_loss: 1630.4987
# Epoch 18/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - loss: 2358.4419 - val_loss: 1630.3527
# Epoch 19/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - loss: 2505.4294 - val_loss: 1630.2252
# Epoch 20/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - loss: 2756.2690 - val_loss: 1630.1167
# Epoch 21/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - loss: 2426.1536 - val_loss: 1630.0244
# Epoch 22/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 2644.5110 - val_loss: 1629.9419
# Epoch 23/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 2431.2925 - val_loss: 1629.8737
# Epoch 24/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 2535.5994 - val_loss: 1629.8124
# Epoch 25/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 2173.4058 - val_loss: 1629.7632
# Epoch 26/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 2231.2300 - val_loss: 1629.7183
# Epoch 27/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 2902.7910 - val_loss: 1629.6791
# Epoch 28/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 2446.5786 - val_loss: 1629.6499
# Epoch 29/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 2746.6274 - val_loss: 1629.6185
# Epoch 30/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 2545.4580 - val_loss: 1629.5959
# Epoch 31/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 2477.4634 - val_loss: 1629.5773
# Epoch 32/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 2479.1372 - val_loss: 1629.5570
# Epoch 33/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 2357.2227 - val_loss: 1629.5454
# Epoch 34/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 2533.6194 - val_loss: 1629.5304
# Epoch 35/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 2384.8428 - val_loss: 1629.5198
# Epoch 36/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 2532.8997 - val_loss: 1629.5111
# Epoch 37/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 2431.3315 - val_loss: 1629.5026
# Epoch 38/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 2610.0969 - val_loss: 1629.4955
# Epoch 39/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 2845.6851 - val_loss: 1629.4897
# Epoch 40/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 2318.8318 - val_loss: 1629.4839
# Epoch 41/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 2369.2739 - val_loss: 1629.4801
# Epoch 42/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 2711.7092 - val_loss: 1629.4753
# Epoch 43/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - loss: 2334.6748 - val_loss: 1629.4723
# Epoch 44/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step - loss: 2423.3335 - val_loss: 1629.4691
# Epoch 45/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - loss: 2436.0376 - val_loss: 1629.4661
# Epoch 46/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 135ms/step - loss: 2477.1702 - val_loss: 1629.4650
# Epoch 47/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - loss: 2394.8147 - val_loss: 1629.4617
# Epoch 48/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - loss: 2358.5476 - val_loss: 1629.4598
# Epoch 49/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 2678.4219 - val_loss: 1629.4580
# Epoch 50/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 2544.2483 - val_loss: 1629.4562
# Epoch 51/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 2094.4778 - val_loss: 1629.4561
# Epoch 52/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 2567.7908 - val_loss: 1629.4535
# Epoch 53/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 2216.0427 - val_loss: 1629.4530
# Epoch 54/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 1980.8521 - val_loss: 1629.4515
# Epoch 55/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 2628.3296 - val_loss: 1629.4506
# Epoch 56/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 2334.6055 - val_loss: 1629.4496
# Epoch 57/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 2326.5139 - val_loss: 1629.4493
# Epoch 58/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 2722.2058 - val_loss: 1629.4480
# Epoch 59/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 2059.4128 - val_loss: 1629.4469
# Epoch 60/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 2529.0344 - val_loss: 1629.4465
# Epoch 61/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 2776.7144 - val_loss: 1629.4457
# Epoch 62/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 2681.3455 - val_loss: 1629.4456
# Epoch 63/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 2641.6860 - val_loss: 1629.4446
# Epoch 64/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 2562.6711 - val_loss: 1629.4441
# Epoch 65/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 2615.1155 - val_loss: 1629.4429
# Epoch 66/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 2614.9844 - val_loss: 1629.4430
# Epoch 67/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 2368.2273 - val_loss: 1629.4425
# Epoch 68/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 2353.1365 - val_loss: 1629.4420
# Epoch 69/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 2488.4897 - val_loss: 1629.4407
# Epoch 70/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 2402.5562 - val_loss: 1629.4415
# Epoch 71/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - loss: 2242.8286 - val_loss: 1629.4402
# Epoch 72/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 134ms/step - loss: 2210.1794 - val_loss: 1629.4402
# Epoch 73/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - loss: 2237.1484 - val_loss: 1629.4396
# Epoch 74/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step - loss: 2852.5950 - val_loss: 1629.4398
# Epoch 75/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 2454.0696 - val_loss: 1629.4397
# Epoch 76/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 2648.1475 - val_loss: 1629.4382
# Epoch 77/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 2641.5715 - val_loss: 1629.4392
# Epoch 78/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 2806.4241 - val_loss: 1629.4377
# Epoch 79/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 2780.9348 - val_loss: 1629.4385
# Epoch 80/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 2412.2273 - val_loss: 1629.4371
# Epoch 81/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 2369.3845 - val_loss: 1629.4380
# Epoch 82/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 2649.2329 - val_loss: 1629.4370
# Epoch 83/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 2598.6038 - val_loss: 1629.4376
# Epoch 84/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 2655.0347 - val_loss: 1629.4373
# Epoch 85/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 2495.1597 - val_loss: 1629.4365
# Epoch 86/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 2289.1494 - val_loss: 1629.4366
# Epoch 87/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 2429.0459 - val_loss: 1629.4366
# Epoch 88/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 1869.3027 - val_loss: 1629.4359
# Epoch 89/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 2552.8101 - val_loss: 1629.4369
# Epoch 90/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 2333.5410 - val_loss: 1629.4353
# Epoch 91/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 2371.2886 - val_loss: 1629.4357
# Epoch 92/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 2853.9822 - val_loss: 1629.4348
# Epoch 93/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 2611.7856 - val_loss: 1629.4353
# Epoch 94/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - loss: 2288.7429 - val_loss: 1629.4351
# Epoch 95/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - loss: 2436.6262 - val_loss: 1629.4343
# Epoch 96/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 135ms/step - loss: 2344.8604 - val_loss: 1629.4353
# Epoch 97/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step - loss: 2288.0474 - val_loss: 1629.4346
# Epoch 98/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 138ms/step - loss: 2759.4834 - val_loss: 1629.4342
# Epoch 99/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 2335.1245 - val_loss: 1629.4348
# Epoch 100/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 2736.8284 - val_loss: 1629.4335
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
y_train_0 = df0_train['disease']
y_test_0 = df0_test['disease']

report_dict_0 = evaluate_model_rf(mirna_features_intermediate_train_0, mirna_features_intermediate_test_0, y_train_0, y_test_0)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.80      0.77       208
#            1       0.29      0.25      0.27        60
#            2       0.39      0.30      0.34        23
#
#     accuracy                           0.65       291
#    macro avg       0.48      0.45      0.46       291
# weighted avg       0.63      0.65      0.64       291

# %% [markdown]
# # Fold 1 - Results

# %%
df1_train = pd.read_csv('train_fold_1.csv')
df1_test = pd.read_csv('test_fold_1.csv')

df_mirna_preprocessed_train_1 = process_dataframe(df1_train)
df_mirna_preprocessed_test_1 = process_dataframe(df1_test)


mirna_features_intermediate_train_1, mirna_features_intermediate_test_1 = generate_intermediate_feature(df_mirna_preprocessed_train_1, df_mirna_preprocessed_test_1)
# Out:
# Epoch 1/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - loss: 2387.2705 - val_loss: 2471.3718
# Epoch 2/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 2650.2141 - val_loss: 2463.4463
# Epoch 3/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 2471.1724 - val_loss: 2457.8877
# Epoch 4/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 2155.1631 - val_loss: 2453.6621
# Epoch 5/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 2361.4937 - val_loss: 2450.4519
# Epoch 6/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - loss: 2771.0742 - val_loss: 2448.1145
# Epoch 7/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - loss: 1965.7628 - val_loss: 2446.4697
# Epoch 8/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 135ms/step - loss: 2440.0503 - val_loss: 2445.3213
# Epoch 9/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - loss: 2577.7866 - val_loss: 2444.4978
# Epoch 10/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step - loss: 2519.9458 - val_loss: 2443.8887
# Epoch 11/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 2687.2820 - val_loss: 2443.4231
# Epoch 12/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 2152.5793 - val_loss: 2443.0518
# Epoch 13/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 2032.5930 - val_loss: 2442.7441
# Epoch 14/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 2314.4990 - val_loss: 2442.4834
# Epoch 15/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 2161.6570 - val_loss: 2442.2595
# Epoch 16/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 2365.8853 - val_loss: 2442.0662
# Epoch 17/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 2435.2922 - val_loss: 2441.8979
# Epoch 18/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 2194.2625 - val_loss: 2441.7517
# Epoch 19/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 2272.6121 - val_loss: 2441.6238
# Epoch 20/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 2016.8375 - val_loss: 2441.5151
# Epoch 21/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 1938.9194 - val_loss: 2441.4194
# Epoch 22/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 2309.1714 - val_loss: 2441.3350
# Epoch 23/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 2596.6497 - val_loss: 2441.2649
# Epoch 24/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 2158.6165 - val_loss: 2441.2034
# Epoch 25/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 2335.5095 - val_loss: 2441.1472
# Epoch 26/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 2051.4458 - val_loss: 2441.1008
# Epoch 27/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 2074.7349 - val_loss: 2441.0596
# Epoch 28/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 2002.0533 - val_loss: 2441.0242
# Epoch 29/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 2379.8787 - val_loss: 2440.9946
# Epoch 30/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 1685.1680 - val_loss: 2440.9661
# Epoch 31/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 134ms/step - loss: 2371.7322 - val_loss: 2440.9426
# Epoch 32/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - loss: 2090.1316 - val_loss: 2440.9207
# Epoch 33/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - loss: 2426.4343 - val_loss: 2440.9028
# Epoch 34/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - loss: 2226.6387 - val_loss: 2440.8875
# Epoch 35/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 134ms/step - loss: 2195.1970 - val_loss: 2440.8716
# Epoch 36/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - loss: 2632.3430 - val_loss: 2440.8582
# Epoch 37/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 2388.1750 - val_loss: 2440.8486
# Epoch 38/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 2276.4924 - val_loss: 2440.8364
# Epoch 39/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 1847.9390 - val_loss: 2440.8264
# Epoch 40/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 2282.7036 - val_loss: 2440.8181
# Epoch 41/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 2154.5613 - val_loss: 2440.8096
# Epoch 42/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 1749.7709 - val_loss: 2440.8032
# Epoch 43/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 2311.8157 - val_loss: 2440.7957
# Epoch 44/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 2844.3379 - val_loss: 2440.7891
# Epoch 45/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 2041.6992 - val_loss: 2440.7839
# Epoch 46/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 2293.4497 - val_loss: 2440.7778
# Epoch 47/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 2010.8107 - val_loss: 2440.7727
# Epoch 48/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 2285.3914 - val_loss: 2440.7683
# Epoch 49/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 2285.9685 - val_loss: 2440.7632
# Epoch 50/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 2464.9490 - val_loss: 2440.7585
# Epoch 51/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 2185.9382 - val_loss: 2440.7544
# Epoch 52/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 2516.1238 - val_loss: 2440.7498
# Epoch 53/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 2603.9314 - val_loss: 2440.7461
# Epoch 54/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 135ms/step - loss: 1774.2158 - val_loss: 2440.7422
# Epoch 55/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - loss: 2705.0081 - val_loss: 2440.7383
# Epoch 56/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - loss: 2120.8132 - val_loss: 2440.7351
# Epoch 57/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 2498.5649 - val_loss: 2440.7310
# Epoch 58/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 2239.7500 - val_loss: 2440.7288
# Epoch 59/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 2115.8274 - val_loss: 2440.7251
# Epoch 60/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 2403.1621 - val_loss: 2440.7227
# Epoch 61/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 2494.6038 - val_loss: 2440.7188
# Epoch 62/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 2645.9302 - val_loss: 2440.7170
# Epoch 63/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 1989.9495 - val_loss: 2440.7136
# Epoch 64/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 2439.2036 - val_loss: 2440.7117
# Epoch 65/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 2240.5557 - val_loss: 2440.7080
# Epoch 66/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 2190.3760 - val_loss: 2440.7061
# Epoch 67/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 2668.4309 - val_loss: 2440.7031
# Epoch 68/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 2376.8157 - val_loss: 2440.7014
# Epoch 69/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 2626.1541 - val_loss: 2440.6985
# Epoch 70/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 2305.9473 - val_loss: 2440.6973
# Epoch 71/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 2409.6343 - val_loss: 2440.6938
# Epoch 72/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 2623.7864 - val_loss: 2440.6921
# Epoch 73/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 2202.6123 - val_loss: 2440.6902
# Epoch 74/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 2422.5535 - val_loss: 2440.6885
# Epoch 75/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 2467.1819 - val_loss: 2440.6860
# Epoch 76/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 2448.5396 - val_loss: 2440.6846
# Epoch 77/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step - loss: 2455.8870 - val_loss: 2440.6824
# Epoch 78/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 138ms/step - loss: 2074.4639 - val_loss: 2440.6812
# Epoch 79/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 2633.0811 - val_loss: 2440.6787
# Epoch 80/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - loss: 2520.3455 - val_loss: 2440.6782
# Epoch 81/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - loss: 1988.2831 - val_loss: 2440.6758
# Epoch 82/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 2001.7577 - val_loss: 2440.6741
# Epoch 83/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 2383.9775 - val_loss: 2440.6724
# Epoch 84/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 2437.6780 - val_loss: 2440.6714
# Epoch 85/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 2188.5691 - val_loss: 2440.6702
# Epoch 86/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1909.0793 - val_loss: 2440.6680
# Epoch 87/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 2051.5300 - val_loss: 2440.6670
# Epoch 88/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 2212.7449 - val_loss: 2440.6653
# Epoch 89/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 2185.3733 - val_loss: 2440.6646
# Epoch 90/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 2402.5686 - val_loss: 2440.6619
# Epoch 91/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 2621.1360 - val_loss: 2440.6616
# Epoch 92/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 1998.1794 - val_loss: 2440.6606
# Epoch 93/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 1991.3041 - val_loss: 2440.6584
# Epoch 94/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 2216.5508 - val_loss: 2440.6587
# Epoch 95/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 2050.9724 - val_loss: 2440.6562
# Epoch 96/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 1785.1030 - val_loss: 2440.6558
# Epoch 97/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 2270.7632 - val_loss: 2440.6548
# Epoch 98/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 2630.6064 - val_loss: 2440.6541
# Epoch 99/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 2533.6150 - val_loss: 2440.6526
# Epoch 100/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 2289.3079 - val_loss: 2440.6514
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
y_train_1 = df1_train['disease']
y_test_1 = df1_test['disease']

report_dict_1 = evaluate_model_rf(mirna_features_intermediate_train_1, mirna_features_intermediate_test_1, y_train_1, y_test_1)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.77      0.75       208
#            1       0.19      0.17      0.18        60
#            2       0.72      0.57      0.63        23
#
#     accuracy                           0.63       291
#    macro avg       0.55      0.50      0.52       291
# weighted avg       0.62      0.63      0.63       291

# %% [markdown]
# # Fold 2 - Results

# %%
df2_train = pd.read_csv('train_fold_2.csv')
df2_test = pd.read_csv('test_fold_2.csv')

df_mirna_preprocessed_train_2 = process_dataframe(df2_train)
df_mirna_preprocessed_test_2 = process_dataframe(df2_test)


mirna_features_intermediate_train_2, mirna_features_intermediate_test_2 = generate_intermediate_feature(df_mirna_preprocessed_train_2, df_mirna_preprocessed_test_2)
# Out:
# Epoch 1/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 125ms/step - loss: 2082.6584 - val_loss: 42.5303
# Epoch 2/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 2197.5496 - val_loss: 34.5478
# Epoch 3/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 1903.5693 - val_loss: 28.9814
# Epoch 4/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 2027.7169 - val_loss: 24.7533
# Epoch 5/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 2256.3389 - val_loss: 21.5405
# Epoch 6/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 2214.5366 - val_loss: 19.2057
# Epoch 7/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 1600.6093 - val_loss: 17.5651
# Epoch 8/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 1859.3234 - val_loss: 16.4180
# Epoch 9/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 2314.3325 - val_loss: 15.6022
# Epoch 10/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 1658.4410 - val_loss: 15.0008
# Epoch 11/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 1976.0004 - val_loss: 14.5412
# Epoch 12/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 2012.8015 - val_loss: 14.1759
# Epoch 13/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 2241.9333 - val_loss: 13.8735
# Epoch 14/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 2249.5496 - val_loss: 13.6175
# Epoch 15/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 1716.5138 - val_loss: 13.3994
# Epoch 16/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - loss: 2575.3911 - val_loss: 13.2069
# Epoch 17/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - loss: 1784.1212 - val_loss: 13.0414
# Epoch 18/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - loss: 1943.5470 - val_loss: 12.9008
# Epoch 19/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - loss: 2219.6775 - val_loss: 12.7759
# Epoch 20/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - loss: 2090.5430 - val_loss: 12.6691
# Epoch 21/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step - loss: 1901.8347 - val_loss: 12.5758
# Epoch 22/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1916.2841 - val_loss: 12.4952
# Epoch 23/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1889.3452 - val_loss: 12.4268
# Epoch 24/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 1741.4348 - val_loss: 12.3654
# Epoch 25/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 1823.7251 - val_loss: 12.3154
# Epoch 26/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 2056.3315 - val_loss: 12.2698
# Epoch 27/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 2071.5024 - val_loss: 12.2284
# Epoch 28/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 2078.8328 - val_loss: 12.1967
# Epoch 29/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 2186.3303 - val_loss: 12.1661
# Epoch 30/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 1933.9263 - val_loss: 12.1404
# Epoch 31/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 1790.3907 - val_loss: 12.1198
# Epoch 32/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1799.5475 - val_loss: 12.0988
# Epoch 33/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 2327.3193 - val_loss: 12.0824
# Epoch 34/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 2002.4656 - val_loss: 12.0660
# Epoch 35/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 2310.1868 - val_loss: 12.0547
# Epoch 36/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1816.4250 - val_loss: 12.0420
# Epoch 37/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 2083.7781 - val_loss: 12.0303
# Epoch 38/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 2361.5740 - val_loss: 12.0221
# Epoch 39/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 1948.3562 - val_loss: 12.0117
# Epoch 40/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 2015.0771 - val_loss: 12.0052
# Epoch 41/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 2275.9167 - val_loss: 11.9983
# Epoch 42/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - loss: 1979.6877 - val_loss: 11.9919
# Epoch 43/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - loss: 1942.8947 - val_loss: 11.9855
# Epoch 44/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - loss: 2580.9702 - val_loss: 11.9795
# Epoch 45/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - loss: 2001.9790 - val_loss: 11.9750
# Epoch 46/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - loss: 1946.5226 - val_loss: 11.9701
# Epoch 47/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - loss: 1809.6915 - val_loss: 11.9653
# Epoch 48/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 2448.3228 - val_loss: 11.9612
# Epoch 49/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 2211.8728 - val_loss: 11.9580
# Epoch 50/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1896.4406 - val_loss: 11.9541
# Epoch 51/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 1863.8789 - val_loss: 11.9501
# Epoch 52/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 2251.6399 - val_loss: 11.9477
# Epoch 53/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 1979.8273 - val_loss: 11.9438
# Epoch 54/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 2007.0524 - val_loss: 11.9399
# Epoch 55/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 1810.8508 - val_loss: 11.9368
# Epoch 56/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 2475.9844 - val_loss: 11.9342
# Epoch 57/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 1968.7772 - val_loss: 11.9323
# Epoch 58/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1886.8621 - val_loss: 11.9285
# Epoch 59/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 1820.8492 - val_loss: 11.9260
# Epoch 60/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 2112.1057 - val_loss: 11.9248
# Epoch 61/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 2102.7085 - val_loss: 11.9222
# Epoch 62/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 2118.3955 - val_loss: 11.9196
# Epoch 63/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 2104.9590 - val_loss: 11.9179
# Epoch 64/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1716.6146 - val_loss: 11.9147
# Epoch 65/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - loss: 2324.3333 - val_loss: 11.9144
# Epoch 66/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - loss: 2290.1562 - val_loss: 11.9106
# Epoch 67/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - loss: 2419.9387 - val_loss: 11.9101
# Epoch 68/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 1631.2858 - val_loss: 11.9084
# Epoch 69/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 2145.5581 - val_loss: 11.9061
# Epoch 70/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: 2249.5603 - val_loss: 11.9035
# Epoch 71/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - loss: 2009.8586 - val_loss: 11.9037
# Epoch 72/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 2230.9324 - val_loss: 11.9002
# Epoch 73/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 1911.1079 - val_loss: 11.8998
# Epoch 74/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 2489.0950 - val_loss: 11.8978
# Epoch 75/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1984.8252 - val_loss: 11.8965
# Epoch 76/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 1991.8862 - val_loss: 11.8953
# Epoch 77/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 2366.3445 - val_loss: 11.8932
# Epoch 78/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 2150.4834 - val_loss: 11.8917
# Epoch 79/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 2038.8313 - val_loss: 11.8912
# Epoch 80/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 2105.9211 - val_loss: 11.8903
# Epoch 81/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 2046.2330 - val_loss: 11.8889
# Epoch 82/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 2298.9268 - val_loss: 11.8879
# Epoch 83/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1825.9882 - val_loss: 11.8866
# Epoch 84/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 1837.2361 - val_loss: 11.8848
# Epoch 85/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 2104.7791 - val_loss: 11.8840
# Epoch 86/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1992.4066 - val_loss: 11.8839
# Epoch 87/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 2254.6917 - val_loss: 11.8812
# Epoch 88/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 2236.7905 - val_loss: 11.8816
# Epoch 89/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1980.4193 - val_loss: 11.8802
# Epoch 90/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 1710.3466 - val_loss: 11.8796
# Epoch 91/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 2060.1296 - val_loss: 11.8774
# Epoch 92/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - loss: 1739.6104 - val_loss: 11.8785
# Epoch 93/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - loss: 1998.5225 - val_loss: 11.8759
# Epoch 94/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - loss: 2218.8818 - val_loss: 11.8771
# Epoch 95/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - loss: 2231.2402 - val_loss: 11.8740
# Epoch 96/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - loss: 2064.9963 - val_loss: 11.8745
# Epoch 97/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - loss: 2162.0493 - val_loss: 11.8727
# Epoch 98/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 1972.4460 - val_loss: 11.8725
# Epoch 99/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 1580.6876 - val_loss: 11.8718
# Epoch 100/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 1974.0629 - val_loss: 11.8705
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step

# %%
y_train_2 = df2_train['disease']
y_test_2 = df2_test['disease']

report_dict_2 = evaluate_model_rf(mirna_features_intermediate_train_2, mirna_features_intermediate_test_2, y_train_2, y_test_2)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.81      0.89       190
#            1       0.00      0.00      0.00         0
#            2       0.00      0.00      0.00         0
#
#     accuracy                           0.81       190
#    macro avg       0.33      0.27      0.30       190
# weighted avg       1.00      0.81      0.89       190

# %% [markdown]
# # Fold 3 - Results

# %%
df3_train = pd.read_csv('train_fold_3.csv')
df3_test = pd.read_csv('test_fold_3.csv')

df_mirna_preprocessed_train_3 = process_dataframe(df3_train)
df_mirna_preprocessed_test_3 = process_dataframe(df3_test)


mirna_features_intermediate_train_3, mirna_features_intermediate_test_3 = generate_intermediate_feature(df_mirna_preprocessed_train_3, df_mirna_preprocessed_test_3)
# Out:
# Epoch 1/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step - loss: 2296.5437 - val_loss: 2711.4924
# Epoch 2/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 2023.7222 - val_loss: 2703.6882
# Epoch 3/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 2049.7219 - val_loss: 2698.1648
# Epoch 4/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 1990.4137 - val_loss: 2693.9526
# Epoch 5/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 2211.2859 - val_loss: 2690.7627
# Epoch 6/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 136ms/step - loss: 1976.2162 - val_loss: 2688.4478
# Epoch 7/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 2481.9282 - val_loss: 2686.8208
# Epoch 8/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - loss: 2056.8779 - val_loss: 2685.6777
# Epoch 9/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - loss: 2155.6226 - val_loss: 2684.8560
# Epoch 10/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 2139.5679 - val_loss: 2684.2483
# Epoch 11/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 1969.0803 - val_loss: 2683.7776
# Epoch 12/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 2043.5031 - val_loss: 2683.4036
# Epoch 13/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 2360.4434 - val_loss: 2683.0911
# Epoch 14/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 2227.9941 - val_loss: 2682.8218
# Epoch 15/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 2263.8418 - val_loss: 2682.5908
# Epoch 16/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 2055.5283 - val_loss: 2682.3899
# Epoch 17/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 1775.4275 - val_loss: 2682.2131
# Epoch 18/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 2193.9819 - val_loss: 2682.0588
# Epoch 19/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 2077.8606 - val_loss: 2681.9238
# Epoch 20/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 1826.3463 - val_loss: 2681.8074
# Epoch 21/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 2483.6504 - val_loss: 2681.7014
# Epoch 22/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 1940.3258 - val_loss: 2681.6128
# Epoch 23/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 2294.7783 - val_loss: 2681.5352
# Epoch 24/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 2180.0259 - val_loss: 2681.4644
# Epoch 25/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 2612.3032 - val_loss: 2681.4062
# Epoch 26/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 2484.6760 - val_loss: 2681.3542
# Epoch 27/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 2251.7810 - val_loss: 2681.3052
# Epoch 28/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 2246.0449 - val_loss: 2681.2668
# Epoch 29/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 2244.9529 - val_loss: 2681.2310
# Epoch 30/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - loss: 2390.8726 - val_loss: 2681.2009
# Epoch 31/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - loss: 2210.3328 - val_loss: 2681.1733
# Epoch 32/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 2473.2944 - val_loss: 2681.1489
# Epoch 33/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - loss: 2250.3645 - val_loss: 2681.1289
# Epoch 34/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 137ms/step - loss: 2002.8182 - val_loss: 2681.1096
# Epoch 35/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 130ms/step - loss: 2192.1987 - val_loss: 2681.0925
# Epoch 36/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 2700.0264 - val_loss: 2681.0776
# Epoch 37/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 2260.0959 - val_loss: 2681.0649
# Epoch 38/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 2101.7434 - val_loss: 2681.0527
# Epoch 39/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 2010.7590 - val_loss: 2681.0422
# Epoch 40/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 2115.1042 - val_loss: 2681.0320
# Epoch 41/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 2284.7302 - val_loss: 2681.0244
# Epoch 42/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 2165.3918 - val_loss: 2681.0161
# Epoch 43/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 2225.5515 - val_loss: 2681.0093
# Epoch 44/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 2285.1365 - val_loss: 2681.0032
# Epoch 45/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 2507.0610 - val_loss: 2680.9966
# Epoch 46/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 2152.8601 - val_loss: 2680.9900
# Epoch 47/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 2494.3684 - val_loss: 2680.9858
# Epoch 48/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 2558.7058 - val_loss: 2680.9805
# Epoch 49/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 2131.6597 - val_loss: 2680.9778
# Epoch 50/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 2229.4434 - val_loss: 2680.9727
# Epoch 51/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 2603.1272 - val_loss: 2680.9683
# Epoch 52/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 2128.0439 - val_loss: 2680.9673
# Epoch 53/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 2531.8857 - val_loss: 2680.9624
# Epoch 54/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 2229.9182 - val_loss: 2680.9600
# Epoch 55/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 2359.1133 - val_loss: 2680.9558
# Epoch 56/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 1958.0231 - val_loss: 2680.9534
# Epoch 57/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - loss: 2383.8635 - val_loss: 2680.9519
# Epoch 58/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - loss: 2428.1104 - val_loss: 2680.9475
# Epoch 59/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step - loss: 2045.4425 - val_loss: 2680.9468
# Epoch 60/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 134ms/step - loss: 2077.9277 - val_loss: 2680.9438
# Epoch 61/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 138ms/step - loss: 1878.8971 - val_loss: 2680.9419
# Epoch 62/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 1926.7483 - val_loss: 2680.9409
# Epoch 63/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 2178.4097 - val_loss: 2680.9375
# Epoch 64/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 1746.6473 - val_loss: 2680.9382
# Epoch 65/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 2478.1433 - val_loss: 2680.9346
# Epoch 66/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 2120.4609 - val_loss: 2680.9341
# Epoch 67/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 1624.7313 - val_loss: 2680.9314
# Epoch 68/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 1888.5605 - val_loss: 2680.9307
# Epoch 69/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 2741.2349 - val_loss: 2680.9285
# Epoch 70/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 2431.0137 - val_loss: 2680.9280
# Epoch 71/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 2360.5063 - val_loss: 2680.9265
# Epoch 72/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 2276.7136 - val_loss: 2680.9258
# Epoch 73/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1785.3138 - val_loss: 2680.9238
# Epoch 74/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 2229.8435 - val_loss: 2680.9233
# Epoch 75/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 2381.5933 - val_loss: 2680.9221
# Epoch 76/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 2141.3499 - val_loss: 2680.9211
# Epoch 77/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 2026.3781 - val_loss: 2680.9199
# Epoch 78/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 2317.6946 - val_loss: 2680.9197
# Epoch 79/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 1806.6771 - val_loss: 2680.9187
# Epoch 80/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 2373.3840 - val_loss: 2680.9180
# Epoch 81/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 2044.2357 - val_loss: 2680.9170
# Epoch 82/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - loss: 2230.6658 - val_loss: 2680.9167
# Epoch 83/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step - loss: 2064.1233 - val_loss: 2680.9163
# Epoch 84/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 134ms/step - loss: 2428.7029 - val_loss: 2680.9146
# Epoch 85/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 2410.6589 - val_loss: 2680.9138
# Epoch 86/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 2345.0903 - val_loss: 2680.9136
# Epoch 87/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 2235.7646 - val_loss: 2680.9138
# Epoch 88/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 2021.2759 - val_loss: 2680.9121
# Epoch 89/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 2507.7827 - val_loss: 2680.9126
# Epoch 90/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 2066.1738 - val_loss: 2680.9109
# Epoch 91/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 1932.5909 - val_loss: 2680.9109
# Epoch 92/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 2044.2437 - val_loss: 2680.9119
# Epoch 93/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 2264.2861 - val_loss: 2680.9097
# Epoch 94/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 2154.5552 - val_loss: 2680.9109
# Epoch 95/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 1795.2888 - val_loss: 2680.9089
# Epoch 96/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 2266.9731 - val_loss: 2680.9102
# Epoch 97/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 2006.3450 - val_loss: 2680.9084
# Epoch 98/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 2406.2727 - val_loss: 2680.9084
# Epoch 99/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 2396.1387 - val_loss: 2680.9075
# Epoch 100/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 2407.7314 - val_loss: 2680.9072
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
y_train_3 = df3_train['disease']
y_test_3 = df3_test['disease']

report_dict_3 = evaluate_model_rf(mirna_features_intermediate_train_3, mirna_features_intermediate_test_3, y_train_3, y_test_3)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.81      0.78       207
#            1       0.22      0.18      0.20        60
#            2       0.75      0.52      0.62        23
#
#     accuracy                           0.66       290
#    macro avg       0.57      0.50      0.53       290
# weighted avg       0.64      0.66      0.64       290

# %% [markdown]
# # Fold 4 - Results

# %%
df4_train = pd.read_csv('train_fold_4.csv')
df4_test = pd.read_csv('test_fold_4.csv')

df_mirna_preprocessed_train_4 = process_dataframe(df4_train)
df_mirna_preprocessed_test_4 = process_dataframe(df4_test)


mirna_features_intermediate_train_4, mirna_features_intermediate_test_4 = generate_intermediate_feature(df_mirna_preprocessed_train_4, df_mirna_preprocessed_test_4)
# Out:
# Epoch 1/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step - loss: 2489.2410 - val_loss: 1554.4005
# Epoch 2/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 2206.0264 - val_loss: 1546.3662
# Epoch 3/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 2166.4685 - val_loss: 1540.8131
# Epoch 4/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 2641.8350 - val_loss: 1536.6217
# Epoch 5/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 2568.0898 - val_loss: 1533.4307
# Epoch 6/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 2623.6538 - val_loss: 1531.1072
# Epoch 7/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 2765.2224 - val_loss: 1529.4764
# Epoch 8/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 2477.7583 - val_loss: 1528.3384
# Epoch 9/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 2458.2324 - val_loss: 1527.5269
# Epoch 10/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 2640.5681 - val_loss: 1526.9275
# Epoch 11/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 2454.2844 - val_loss: 1526.4666
# Epoch 12/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 2319.6919 - val_loss: 1526.0979
# Epoch 13/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 2553.3906 - val_loss: 1525.7930
# Epoch 14/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 2482.0154 - val_loss: 1525.5328
# Epoch 15/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 2367.0874 - val_loss: 1525.3064
# Epoch 16/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - loss: 2728.0403 - val_loss: 1525.1095
# Epoch 17/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 136ms/step - loss: 2348.6523 - val_loss: 1524.9391
# Epoch 18/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - loss: 2665.0667 - val_loss: 1524.7866
# Epoch 19/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - loss: 2537.8108 - val_loss: 1524.6561
# Epoch 20/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - loss: 2507.2053 - val_loss: 1524.5408
# Epoch 21/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 138ms/step - loss: 3022.5046 - val_loss: 1524.4386
# Epoch 22/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 2504.4182 - val_loss: 1524.3500
# Epoch 23/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 2961.1316 - val_loss: 1524.2720
# Epoch 24/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 2942.1294 - val_loss: 1524.2029
# Epoch 25/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 2266.4395 - val_loss: 1524.1434
# Epoch 26/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 2578.0278 - val_loss: 1524.0911
# Epoch 27/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 2577.4004 - val_loss: 1524.0420
# Epoch 28/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 2379.6055 - val_loss: 1524.0024
# Epoch 29/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 2650.1572 - val_loss: 1523.9646
# Epoch 30/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 2710.3330 - val_loss: 1523.9324
# Epoch 31/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 2345.8057 - val_loss: 1523.9021
# Epoch 32/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 2977.8667 - val_loss: 1523.8767
# Epoch 33/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 2700.4185 - val_loss: 1523.8531
# Epoch 34/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 2228.5669 - val_loss: 1523.8313
# Epoch 35/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 2635.5105 - val_loss: 1523.8129
# Epoch 36/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 2722.8723 - val_loss: 1523.7946
# Epoch 37/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 2590.9260 - val_loss: 1523.7789
# Epoch 38/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 2494.7866 - val_loss: 1523.7637
# Epoch 39/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 2970.9463 - val_loss: 1523.7504
# Epoch 40/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 2966.2764 - val_loss: 1523.7393
# Epoch 41/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - loss: 2359.7720 - val_loss: 1523.7255
# Epoch 42/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - loss: 2768.6055 - val_loss: 1523.7159
# Epoch 43/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 2087.5312 - val_loss: 1523.7043
# Epoch 44/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - loss: 2628.0559 - val_loss: 1523.6948
# Epoch 45/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step - loss: 2691.6399 - val_loss: 1523.6857
# Epoch 46/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 2062.3225 - val_loss: 1523.6775
# Epoch 47/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 2434.5610 - val_loss: 1523.6685
# Epoch 48/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 2736.7795 - val_loss: 1523.6614
# Epoch 49/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 2213.6646 - val_loss: 1523.6531
# Epoch 50/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 2620.0496 - val_loss: 1523.6465
# Epoch 51/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 2347.4927 - val_loss: 1523.6395
# Epoch 52/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 2670.8462 - val_loss: 1523.6327
# Epoch 53/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 2441.8120 - val_loss: 1523.6277
# Epoch 54/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 2696.2698 - val_loss: 1523.6199
# Epoch 55/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 2530.1128 - val_loss: 1523.6154
# Epoch 56/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 2451.3652 - val_loss: 1523.6089
# Epoch 57/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 2279.5820 - val_loss: 1523.6045
# Epoch 58/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 2552.7690 - val_loss: 1523.5984
# Epoch 59/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 2653.3052 - val_loss: 1523.5939
# Epoch 60/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 2708.8848 - val_loss: 1523.5878
# Epoch 61/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 2563.9146 - val_loss: 1523.5850
# Epoch 62/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 2462.6667 - val_loss: 1523.5789
# Epoch 63/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 2491.1260 - val_loss: 1523.5750
# Epoch 64/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 2830.9556 - val_loss: 1523.5703
# Epoch 65/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 2530.0481 - val_loss: 1523.5671
# Epoch 66/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 2467.0190 - val_loss: 1523.5625
# Epoch 67/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 2533.0225 - val_loss: 1523.5588
# Epoch 68/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 135ms/step - loss: 2451.9487 - val_loss: 1523.5544
# Epoch 69/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 138ms/step - loss: 2553.8906 - val_loss: 1523.5504
# Epoch 70/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - loss: 2690.4019 - val_loss: 1523.5479
# Epoch 71/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step - loss: 2843.7710 - val_loss: 1523.5431
# Epoch 72/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 2410.6677 - val_loss: 1523.5415
# Epoch 73/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 2592.1357 - val_loss: 1523.5360
# Epoch 74/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 2159.4666 - val_loss: 1523.5352
# Epoch 75/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 2747.8999 - val_loss: 1523.5308
# Epoch 76/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 2515.7617 - val_loss: 1523.5282
# Epoch 77/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 2622.8740 - val_loss: 1523.5250
# Epoch 78/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 2736.1919 - val_loss: 1523.5221
# Epoch 79/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 2194.2576 - val_loss: 1523.5194
# Epoch 80/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 2984.5574 - val_loss: 1523.5176
# Epoch 81/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 2672.2979 - val_loss: 1523.5134
# Epoch 82/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 2512.8945 - val_loss: 1523.5120
# Epoch 83/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 2528.7368 - val_loss: 1523.5092
# Epoch 84/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 2373.2871 - val_loss: 1523.5067
# Epoch 85/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 2184.3931 - val_loss: 1523.5032
# Epoch 86/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 2526.2139 - val_loss: 1523.5023
# Epoch 87/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 2050.3777 - val_loss: 1523.4991
# Epoch 88/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 2204.6267 - val_loss: 1523.4977
# Epoch 89/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 2479.9590 - val_loss: 1523.4946
# Epoch 90/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 2155.6577 - val_loss: 1523.4944
# Epoch 91/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 2509.2522 - val_loss: 1523.4904
# Epoch 92/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 2624.3225 - val_loss: 1523.4897
# Epoch 93/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - loss: 2176.6235 - val_loss: 1523.4875
# Epoch 94/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 136ms/step - loss: 2180.7361 - val_loss: 1523.4857
# Epoch 95/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - loss: 2455.6123 - val_loss: 1523.4836
# Epoch 96/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 137ms/step - loss: 2575.0457 - val_loss: 1523.4821
# Epoch 97/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - loss: 2332.0237 - val_loss: 1523.4797
# Epoch 98/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 2587.3555 - val_loss: 1523.4789
# Epoch 99/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 2784.7217 - val_loss: 1523.4766
# Epoch 100/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 2335.6995 - val_loss: 1523.4755
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
y_train_4 = df4_train['disease']
y_test_4 = df4_test['disease']

report_dict_4 = evaluate_model_rf(mirna_features_intermediate_train_4, mirna_features_intermediate_test_4, y_train_4, y_test_4)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.85      0.80       207
#            1       0.32      0.23      0.27        60
#            2       0.67      0.35      0.46        23
#
#     accuracy                           0.68       290
#    macro avg       0.58      0.48      0.51       290
# weighted avg       0.66      0.68      0.66       290

# %%
print(" Results for MLP Classifier for each fold")
report_MLP_dict_0 = evaluate_model_mlp(mirna_features_intermediate_train_0, mirna_features_intermediate_test_0, y_train_0, y_test_0)
report_MLP_dict_1 = evaluate_model_mlp(mirna_features_intermediate_train_1, mirna_features_intermediate_test_1, y_train_1, y_test_1)
report_MLP_dict_2 = evaluate_model_mlp(mirna_features_intermediate_train_2, mirna_features_intermediate_test_2, y_train_2, y_test_2)
report_MLP_dict_3 = evaluate_model_mlp(mirna_features_intermediate_train_3, mirna_features_intermediate_test_3, y_train_3, y_test_3)
report_MLP_dict_4 = evaluate_model_mlp(mirna_features_intermediate_train_4, mirna_features_intermediate_test_4, y_train_4, y_test_4)
# Out:
#  Results for MLP Classifier for each fold
#               precision    recall  f1-score   support
#
#            0       0.71      1.00      0.83       208
#            1       0.00      0.00      0.00        60
#            2       0.00      0.00      0.00        23
#
#     accuracy                           0.71       291
#    macro avg       0.24      0.33      0.28       291
# weighted avg       0.51      0.71      0.60       291
#
#               precision    recall  f1-score   support
#
#            0       0.74      1.00      0.85       208
#            1       0.00      0.00      0.00        60
#            2       1.00      0.48      0.65        23
#
#     accuracy                           0.75       291
#    macro avg       0.58      0.49      0.50       291
# weighted avg       0.61      0.75      0.66       291
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       190
#
#     accuracy                           1.00       190
#    macro avg       1.00      1.00      1.00       190
# weighted avg       1.00      1.00      1.00       190
#
#               precision    recall  f1-score   support
#
#            0       0.68      0.12      0.20       207
#            1       0.00      0.00      0.00        60
#            2       0.09      1.00      0.17        23
#
#     accuracy                           0.17       290
#    macro avg       0.26      0.37      0.12       290
# weighted avg       0.49      0.17      0.16       290
#
#               precision    recall  f1-score   support
#
#            0       0.43      0.01      0.03       207
#            1       0.00      0.00      0.00        60
#            2       0.08      1.00      0.15        23
#
#     accuracy                           0.09       290
#    macro avg       0.17      0.34      0.06       290
# weighted avg       0.31      0.09      0.03       290

# %% [markdown]
# # Average Results

# %%
print("\n \nResults Random Forest Classifier")
print("---------------------------------------- ")
print_average_metrics(report_dict_0, report_dict_1, report_dict_2, report_dict_3, report_dict_4)
# Out:
#
# Results Random Forest Classifier
# ----------------------------------------
# Average Precision Score: 0.5
# Average Recall Score: 0.44
# Average F1 Score: 0.46

# %%
print("\n \n  Average Results MLP  Classifier ")
print("---------------------------------------- ")
print_average_metrics(report_MLP_dict_0, report_MLP_dict_1, report_MLP_dict_2, report_MLP_dict_3, report_MLP_dict_4)
# Out:
#
#   Average Results MLP  Classifier
# ----------------------------------------
# Average Precision Score: 0.45
# Average Recall Score: 0.51
# Average F1 Score: 0.39
